# %%
import arcpy
import warnings
warnings.filterwarnings('ignore')

# %%
arcpy.env.workspace = 'C:/Users/rozan012/Documents/ArcGIS/Projects/Lab0/fgdb_trans_roads_mndot_tis/trans_roads_mndot_tis.gdb'

# %%
arcpy.ListFeatureClasses()
# Out:
# ['STREETS_LOAD']

# %%
arcpy.analysis.Buffer('STREETS_LOAD', 'C:/Users/rozan012/Documents/ArcGIS/Projects/Lab0/buffered.gdb', '100 Meters')
# Out:
# <Result 'C:\\Users\\rozan012\\Documents\\ArcGIS\\Projects\\Lab0\\buffered.shp'>
